# %% [markdown]
# # Wine Analysis

# %% [markdown]
# This notebook aims to analyse a data set regarding the control of the quality and indicate the best wine for the best customer

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# I have downloaded the dataset and the same is also available on my github but the link for the data is:
# https://archive.ics.uci.edu/dataset/186/wine+quality

df_red = pd.read_csv("winequality-red.csv", delimiter=';', header=0)
df_white = pd.read_csv("winequality-white.csv", delimiter=';', header=0)

# %%
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_white.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_red.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# ### df.info()
# function. This function gives a concise summary of the data frame. This method prints information about a data frame including the index D type and columns non-null values, and memory usage.

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# Both dataframes have the same columns, which makes the analysis easier when it comes to comparison.

# %% [markdown]
# The <b>white</b> date frame comes with <b>4898 rows × 12</b> columns and the <b>red</b> with <b>1599 rows × 12 columns</b>.

# %% [markdown]
# 11 Columns are float and one is int which makes analysing the data much easier.

# %% [markdown]
# ### df.describe()
# Now we would like to check the statistical summary of each column to learn about the distribution of data in each column. The statistical metrics can tell the data scientist if there are mathematical issues that may exist, such as extreme outliers and large deviations, the data scientists may have to address these issues later. To get the quick statistics, we use the described method.

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ### df.describe(include="all")
# It is possible to make the described method work for object type columns as well (strings). To enable a summary of all the columns, we could add an argument, include equals, all inside the described function bracket (in this case all our data is numeric so there is no need to use that form).

# %%
# checking specific columns of the dataset, to see if there is a correlation
df_red[['residual sugar', 'alcohol', 'quality']].describe()
# Out:
#        residual sugar      alcohol      quality
# count     1599.000000  1599.000000  1599.000000
# mean         2.538806    10.422983     5.636023
# std          1.409928     1.065668     0.807569
# min          0.900000     8.400000     3.000000
# 25%          1.900000     9.500000     5.000000
# 50%          2.200000    10.200000     6.000000
# 75%          2.600000    11.100000     6.000000
# max         15.500000    14.900000     8.000000

# %% [markdown]
# ## Checking dataset for null values

# %% [markdown]
# Different ways to check for a null value in the dataset

# %%
# Check for Null Values in the Entire DataFrame
null_values_red = df_red.isna()
null_values_white = df_white.isna()
print(null_values_red)
print(null_values_white)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
# Count Null Values in Each Column
null_counts_red = df_red.isna().sum()
null_counts_white = df_white.isna().sum()
print(null_counts_red)
print("-------------")
print(null_counts_white)
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
# -------------
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Count Null Values in the Entire DataFrame
total_nulls_red = df_white.isna().sum().sum()
total_nulls_white = df_red.isna().sum().sum()
print(total_nulls_red)
print(total_nulls_white)
# Out:
# 0
# 0

# %%
# Percentage of Null Values in Each Column
null_percentage_red = df_red.isna().mean() * 100
null_percentage_white = df_white.isna().mean() * 100
print(null_percentage_red)
print("-------------")
print(null_percentage_white)
# Out:
# fixed acidity           0.0
# volatile acidity        0.0
# citric acid             0.0
# residual sugar          0.0
# chlorides               0.0
# free sulfur dioxide     0.0
# total sulfur dioxide    0.0
# density                 0.0
# pH                      0.0
# sulphates               0.0
# alcohol                 0.0
# quality                 0.0
# dtype: float64
# -------------
# fixed acidity           0.0
# volatile acidity        0.0
# citric acid             0.0
# residual sugar          0.0
# chlorides               0.0
# free sulfur dioxide     0.0
# total sulfur dioxide    0.0
# density                 0.0
# pH                      0.0
# sulphates               0.0
# alcohol                 0.0
# quality                 0.0
# dtype: float64

# %% [markdown]
# This dataset, was previously cleaned by its creator, however, checking for null values is the first step of data wrangling/cleaning and part of the data analyst/scientist job.

# %% [markdown]
# ## Binning process

# %% [markdown]
#  Binning is when you group values together

# %% [markdown]
# ### Binning Red Wine

# %%
# Define bins and labels
# let the computer decide what was classified as low, medium and high
bins_defined_function = np.linspace(min(df_red["alcohol"]), max(df_red["alcohol"]), 4) # defined by numpy function
bins_defined = [0,12.5,13.5,30]  #source: https://www.wineinvestment.com/learn/magazine/2019/06/wines-alcohol-levels-explained/
group_names = ["Low", "Medium", "High"]

# %%
# Bin the data
df_red["alcohol-binned"] = pd.cut(df_red["alcohol"], bins_defined_function, labels=group_names, include_lowest = True)

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
df_red["alcohol-binned"].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.xlabel('Alcohol Content Categories')
plt.ylabel('Quantity')
plt.title('Histogram of Binned Alcohol Content')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Bin the data
df_red["alcohol-binned"] = pd.cut(df_red["alcohol"], bins_defined, labels=group_names, include_lowest = True)

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
df_red["alcohol-binned"].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.xlabel('Alcohol Content Categories')
plt.ylabel('Quantity')
plt.title('Histogram of Binned Alcohol Content')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# As you can see, letting the function define the bins for you gives a difference in what you consider low, medium, and high. It all depends on the type of analysis that you are doing and what are your end goals, but if you want to follow strict procedures and measures it is always good to ask and check real world measurements.

# %%
sns.histplot(df_red['alcohol'], kde=True)
# Out:
# C:\Users\dfm_n\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# ### Binning White Wine

# %%
# Define white bins based on source
white_bins  = [0,12.5,13.5,30] #source: https://www.wineinvestment.com/learn/magazine/2019/06/wines-alcohol-levels-explained/
white_group_names = ["Low", "Medium", "High"]

# %%
# checking bins
white_bins
# Out:
# [0, 12.5, 13.5, 30]

# %%
# Bin the data
df_white["alcohol-binned"] = pd.cut(df_white["alcohol"], white_bins, labels=white_group_names, include_lowest = True)

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
df_white["alcohol-binned"].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.xlabel('Alcohol Content Categories')
plt.ylabel('Frequency')
plt.title('Histogram of Binned Alcohol Content')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
sns.histplot(df_white['alcohol'], kde=True)
# Out:
# C:\Users\dfm_n\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
max(df_red["quality"])
# Out:
# 8

# %%
min(df_red["quality"])
# Out:
# 3

# %% [markdown]
# ## binned quality

# %%
# Define bins and labels
# let the computer decide what was classified as low, medium and high
bins_quality = np.linspace(min(df_white["quality"]), max(df_white["quality"]), 4) # defined by numpy function
group_names = ["Low", "Medium", "High"]

# %%
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
bins_quality
# Out:
# array([3., 5., 7., 9.])

# %%
# Bin the data
df_white["quality-binned"] = pd.cut(df_white["quality"], bins_quality, labels= group_names, include_lowest = True)

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
df_white["quality-binned"].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.xlabel('quality Content Categories')
plt.ylabel('Quantity')
plt.title('Histogram of Binned Wine Quality')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
bins_quality
# Out:
# array([3., 5., 7., 9.])

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %% [markdown]
# - Explore features or characteristics to predict wine quality
# - Analyze patterns and run descriptive statistical analysis
# - Group data based on identified parameters and create pivot tables
# - Identify the effect of independent attributes on wine quality

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  alcohol-binned        1599 non-null   category
# dtypes: category(1), float64(11), int64(1)
# memory usage: 151.7 KB

# %%
# Exclude non-numeric columns (as we added a binned column, it is considered a category and 
# does not allow us to see the correlation). to see the correlation you can use the include command and call only numeric values
numeric_df_red = df_red.select_dtypes(include=['float64', 'int64'])

# Compute correlation matrix
correlation_matrix_red = numeric_df_red.corr()

# %%
correlation_matrix_red
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# #### Repeat the same process for white

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  alcohol-binned        4898 non-null   category
#  13  quality-binned        4898 non-null   category
# ...

# %%
# Exclude non-numeric columns (as we added a binned column, it is considered a category and 
# does not allow us to see the correlation). to see the correlation you can use the include command and call only numeric values
numeric_df_white = df_white.select_dtypes(include=['float64', 'int64'])

# Compute correlation matrix
correlation_matrix_white = numeric_df_white.corr()

# %%
correlation_matrix_white
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ### Types of correlation:
# <b>Positive Correlation:</b> As one variable increases, the other also increases. For example, height and weight typically have a positive correlation.
#
# <b>Negative Correlation:</b> As one variable increases, the other decreases. An example is the relationship between the speed of a car and the time taken to reach a destination.
#
# <b>No Correlation:</b> There is no discernible relationship between the variables. For instance, the correlation between the amount of coffee consumed and intelligence.
#
# <b>Perfect Correlation:</b>
#
# Perfect Positive Correlation (r = +1): The variables move together perfectly.
#
# Perfect Negative Correlation (r = -1): One variable moves perfectly in the opposite direction to the other.
#
# <b>Linear Correlation:</b> The relationship between the variables can be represented by a straight line. This is what is typically meant by "correlation" in statistics.

# %% [markdown]
# ## REDS

# %%
sns.regplot(x="quality", y="alcohol", data=df_red)
plt.ylim(0,)
# Out:
# (0.0, 15.225)

# %%
sns.regplot(x="quality", y="pH", data=df_red)
plt.ylim(0,)
# Out:
# (0.0, 4.0735)

# %%
sns.regplot(x="quality", y="citric acid", data=df_red)
plt.ylim(0,)
# Out:
# (0.0, 1.05)

# %%
sns.regplot(x="quality", y="residual sugar", data=df_red)
plt.ylim(0,)
# Out:
# (0.0, 16.23)

# %% [markdown]
# ## WHITES

# %%
sns.regplot(x="quality", y="alcohol", data=df_white)
plt.ylim(0,)
# Out:
# (0.0, 14.51)

# %%
sns.regplot(x="quality", y="free sulfur dioxide", data=df_white)
plt.ylim(0,)
# Out:
# (0.0, 303.35)

# %%
sns.regplot(x="quality", y="chlorides", data=df_white)
plt.ylim(0,)
# Out:
# (0.0, 0.36284999999999995)
